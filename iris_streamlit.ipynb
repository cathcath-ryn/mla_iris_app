# %%
import streamlit as st
import os

st.title("My First Streamlit")
st.write("AI apps")

name=st.text_input("Enter your name")
if st.button("Click"):
    print("hello", name)
# Out:
# 2025-11-12 10:45:41.012 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 10:45:41.722
# ...
#   command:
#
#     streamlit run C:\Users\Ei Phyu Sin Win\anaconda3\envs\cathenv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-12 10:45:41.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 10:45:41.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 10:45:41.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 10:45:41.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-12 10:45:41.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pickle
import os

st.title("Iris Prediction")

def load_model():
    with open('iris_model.pkl','rb') as f:
    model = pickle.load(f)
    return model

s_l = st.number_input("Sepal Length (cm)", min_value= 0.0, max_value=10.0, value=
s_w = st.number_input("Sepal Width (cm)", min_value= 0.0, max_value=10.0, value=
p_l = st.number_input("Petal Length (cm)", min_value= 0.0, max_value=10.0, value=
p_w = st.number_input("Petal Width (cm)", min_value= 0.0, max_value=10.0, value=

if st.button("Predict"):
    arr=[[s_l, s_w, p_l, p_w]]
    iris_model=load_model()
    label_names=['setosa','versicolor','virginica']

    flowers={'setosa':'/images/setosa.jpg',
             'versicolor':'/images/versicolor.jpg',
             'virginica': '/images/virginica.jpg'}
    
    results=iris_model.predict(arr)[0]
    st.write("The predicted result is ",label_names[results])
    st.image(flowers[label_names[results]],caption=["(flower
